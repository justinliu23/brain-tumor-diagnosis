# %% [markdown]
# <a href="https://colab.research.google.com/github/SourLemon23/brain-tumor-diagnosis/blob/master/inception_brain_tumor_diagnosis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import random
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Flatten, Dropout, BatchNormalization
import matplotlib.pyplot as plt

# %%
# Authorize access to mount Google Drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Initialize dataset directories (Google Drive)
training_dir   = r'/content/drive/My Drive/Colab Notebooks/Brain Tumor Diagnosis/brain_tumor_image_set/training'
validation_dir = r'/content/drive/My Drive/Colab Notebooks/Brain Tumor Diagnosis/brain_tumor_image_set/validation'
testing_dir    = r'/content/drive/My Drive/Colab Notebooks/Brain Tumor Diagnosis/brain_tumor_image_set/testing'

# %%
# Store all testing images in a list
testing_img_paths = []

for root, dirs, files in os.walk(testing_dir):
    for filename in files:
        testing_img_paths.append(os.path.abspath(os.path.join(root, filename)))

# Randomize the list
random.shuffle(testing_img_paths)

# %%
# Initialize constants
classes = ['glioma', 'meningioma', 'pituitary']
img_width, img_height = 150, 150
target_size = (img_width, img_height)
input_shape = (img_width, img_height, 3)

batch_size = 20
epochs = 100

# %%
# Augment data
training_data_gen = ImageDataGenerator(rescale=1./255,
                                       horizontal_flip=True,
                                       vertical_flip=True,
                                       zoom_range=0.15,
                                       shear_range=0.15,
                                       rotation_range=360,
                                       width_shift_range=0.15,
                                       height_shift_range=0.15,
                                       validation_split=0.15)

validation_data_gen = ImageDataGenerator(rescale=1./255)

# %%
# Split data
training_generator = training_data_gen.flow_from_directory(training_dir,
                                                           target_size=target_size,
                                                           class_mode='categorical',
                                                           batch_size=batch_size,
                                                           shuffle=True)

validation_generator = validation_data_gen.flow_from_directory(validation_dir,
                                                               target_size=target_size,
                                                               class_mode='categorical',
                                                               batch_size=batch_size,
                                                               shuffle=False)
# Out:
# Found 2460 images belonging to 3 classes.
# Found 150 images belonging to 3 classes.

# %%
# Create a neural network
def create_model():
    model = tf.keras.applications.InceptionV3(include_top=False, weights='imagenet')

    x = model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.3)(x)
    x = Dense(128, activation="relu")(x)
    x = Dense(64, activation="relu")(x)
    predictions = Dense(3, activation="softmax")(x)
    model = Model(inputs=model.input, outputs=predictions)

    return model

# %%
# Print an overall summary of the model
def print_model_summary(model):
    model.summary()

# %%
# Configure model
def compile_model(model):
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

# %%
# Train the model
def fit_model(model):
    history = model.fit(training_generator,
                        epochs=epochs,
                        steps_per_epoch=(training_generator.n/batch_size),
                        validation_data=validation_generator,
                        validation_steps=(validation_generator.n/batch_size))
    
    return history

# %%
# Plot and evaluate the model
def evaluate_model(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(8, 8))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')

    plt.show()

# %%
# Classify a tumor from an MRI scan
def classify_tumor(model, testing_img_paths):
    for i, img_path in enumerate(testing_img_paths):
        img = load_img(
            img_path,
            target_size=target_size)

        img_array = img_to_array(img)
        img_array = preprocess_input(img_array)
        img_array = img_array.reshape((-1, 150, 150, 3))

        predictions = model.predict(img_array)
        class_num = predictions.argmax()

        network_percent_confidence = str(np.max(predictions) * 100)[:4] + '%'
        network_prediction = classes[class_num].capitalize()

        print(f'MRI Scan #{i+1})')

        font = {'family': 'DejaVu Sans',
                'color' : 'red',
                'weight': 'heavy',
                'size'  :  10}
        
        plt.imshow(img)
        plt.title(f'Network Prediction: {network_prediction} ({network_percent_confidence})', fontdict=font)
        plt.show()

# %%
model = create_model()
compile_model(model)
print_model_summary(model)
# Out:
# Model: "functional_21"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, None, None,  0
# __________________________________________________________________________________________________
# conv2d_843 (Conv2D)             (None, None, None, 3 864         input_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_842 (BatchN (None, None, None, 3 96          conv2d_843[0][0]
# __________________________________________________________________________________________________
# activation_842 (Activation)     (None, None, None, 3 0           batch_normalization_842[0][0]
# __________________________________________________________________________________________________
# conv2d_844 (Conv2D)             (None, None, None, 3 9216        activation_842[0][0]
# __________________________________________________________________________________________________
# batch_normalization_843 (BatchN (None, None, None, 3 96          conv2d_844[0][0]
# __________________________________________________________________________________________________
# activation_843 (Activation)     (None, None, None, 3 0           batch_normalization_843[0][0]
# __________________________________________________________________________________________________
# conv2d_845 (Conv2D)             (None, None, None, 6 18432       activation_843[0][0]
# __________________________________________________________________________________________________
# batch_normalization_844 (BatchN (None, None, None, 6 192         conv2d_845[0][0]
# __________________________________________________________________________________________________
# activation_844 (Activation)     (None, None, None, 6 0           batch_normalization_844[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, None, None, 6 0           activation_844[0][0]
# __________________________________________________________________________________________________
# conv2d_846 (Conv2D)             (None, None, None, 8 5120        max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_845 (BatchN (None, None, None, 8 240         conv2d_846[0][0]
# __________________________________________________________________________________________________
# activation_845 (Activation)     (None, None, None, 8 0           batch_normalization_845[0][0]
# __________________________________________________________________________________________________
# conv2d_847 (Conv2D)             (None, None, None, 1 138240      activation_845[0][0]
# __________________________________________________________________________________________________
# batch_normalization_846 (BatchN (None, None, None, 1 576         conv2d_847[0][0]
# __________________________________________________________________________________________________
# activation_846 (Activation)     (None, None, None, 1 0           batch_normalization_846[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_37 (MaxPooling2D) (None, None, None, 1 0           activation_846[0][0]
# __________________________________________________________________________________________________
# conv2d_851 (Conv2D)             (None, None, None, 6 12288       max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_850 (BatchN (None, None, None, 6 192         conv2d_851[0][0]
# __________________________________________________________________________________________________
# activation_850 (Activation)     (None, None, None, 6 0           batch_normalization_850[0][0]
# __________________________________________________________________________________________________
# conv2d_849 (Conv2D)             (None, None, None, 4 9216        max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_852 (Conv2D)             (None, None, None, 9 55296       activation_850[0][0]
# __________________________________________________________________________________________________
# batch_normalization_848 (BatchN (None, None, None, 4 144         conv2d_849[0][0]
# __________________________________________________________________________________________________
# batch_normalization_851 (BatchN (None, None, None, 9 288         conv2d_852[0][0]
# __________________________________________________________________________________________________
# activation_848 (Activation)     (None, None, None, 4 0           batch_normalization_848[0][0]
# __________________________________________________________________________________________________
# activation_851 (Activation)     (None, None, None, 9 0           batch_normalization_851[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_80 (AveragePo (None, None, None, 1 0           max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_848 (Conv2D)             (None, None, None, 6 12288       max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_850 (Conv2D)             (None, None, None, 6 76800       activation_848[0][0]
# __________________________________________________________________________________________________
# conv2d_853 (Conv2D)             (None, None, None, 9 82944       activation_851[0][0]
# __________________________________________________________________________________________________
# conv2d_854 (Conv2D)             (None, None, None, 3 6144        average_pooling2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_847 (BatchN (None, None, None, 6 192         conv2d_848[0][0]
# __________________________________________________________________________________________________
# batch_normalization_849 (BatchN (None, None, None, 6 192         conv2d_850[0][0]
# __________________________________________________________________________________________________
# batch_normalization_852 (BatchN (None, None, None, 9 288         conv2d_853[0][0]
# __________________________________________________________________________________________________
# batch_normalization_853 (BatchN (None, None, None, 3 96          conv2d_854[0][0]
# __________________________________________________________________________________________________
# activation_847 (Activation)     (None, None, None, 6 0           batch_normalization_847[0][0]
# __________________________________________________________________________________________________
# activation_849 (Activation)     (None, None, None, 6 0           batch_normalization_849[0][0]
# __________________________________________________________________________________________________
# activation_852 (Activation)     (None, None, None, 9 0           batch_normalization_852[0][0]
# __________________________________________________________________________________________________
# activation_853 (Activation)     (None, None, None, 3 0           batch_normalization_853[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, None, None, 2 0           activation_847[0][0]
#                                                                  activation_849[0][0]
#                                                                  activation_852[0][0]
#                                                                  activation_853[0][0]
# __________________________________________________________________________________________________
# conv2d_858 (Conv2D)             (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_857 (BatchN (None, None, None, 6 192         conv2d_858[0][0]
# __________________________________________________________________________________________________
# activation_857 (Activation)     (None, None, None, 6 0           batch_normalization_857[0][0]
# __________________________________________________________________________________________________
# conv2d_856 (Conv2D)             (None, None, None, 4 12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_859 (Conv2D)             (None, None, None, 9 55296       activation_857[0][0]
# __________________________________________________________________________________________________
# batch_normalization_855 (BatchN (None, None, None, 4 144         conv2d_856[0][0]
# __________________________________________________________________________________________________
# batch_normalization_858 (BatchN (None, None, None, 9 288         conv2d_859[0][0]
# __________________________________________________________________________________________________
# activation_855 (Activation)     (None, None, None, 4 0           batch_normalization_855[0][0]
# __________________________________________________________________________________________________
# activation_858 (Activation)     (None, None, None, 9 0           batch_normalization_858[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_81 (AveragePo (None, None, None, 2 0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_855 (Conv2D)             (None, None, None, 6 16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_857 (Conv2D)             (None, None, None, 6 76800       activation_855[0][0]
# __________________________________________________________________________________________________
# conv2d_860 (Conv2D)             (None, None, None, 9 82944       activation_858[0][0]
# __________________________________________________________________________________________________
# conv2d_861 (Conv2D)             (None, None, None, 6 16384       average_pooling2d_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_854 (BatchN (None, None, None, 6 192         conv2d_855[0][0]
# __________________________________________________________________________________________________
# batch_normalization_856 (BatchN (None, None, None, 6 192         conv2d_857[0][0]
# __________________________________________________________________________________________________
# batch_normalization_859 (BatchN (None, None, None, 9 288         conv2d_860[0][0]
# __________________________________________________________________________________________________
# batch_normalization_860 (BatchN (None, None, None, 6 192         conv2d_861[0][0]
# __________________________________________________________________________________________________
# activation_854 (Activation)     (None, None, None, 6 0           batch_normalization_854[0][0]
# __________________________________________________________________________________________________
# activation_856 (Activation)     (None, None, None, 6 0           batch_normalization_856[0][0]
# __________________________________________________________________________________________________
# activation_859 (Activation)     (None, None, None, 9 0           batch_normalization_859[0][0]
# __________________________________________________________________________________________________
# activation_860 (Activation)     (None, None, None, 6 0           batch_normalization_860[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, None, None, 2 0           activation_854[0][0]
#                                                                  activation_856[0][0]
#                                                                  activation_859[0][0]
#                                                                  activation_860[0][0]
# __________________________________________________________________________________________________
# conv2d_865 (Conv2D)             (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_864 (BatchN (None, None, None, 6 192         conv2d_865[0][0]
# __________________________________________________________________________________________________
# activation_864 (Activation)     (None, None, None, 6 0           batch_normalization_864[0][0]
# __________________________________________________________________________________________________
# conv2d_863 (Conv2D)             (None, None, None, 4 13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_866 (Conv2D)             (None, None, None, 9 55296       activation_864[0][0]
# __________________________________________________________________________________________________
# batch_normalization_862 (BatchN (None, None, None, 4 144         conv2d_863[0][0]
# __________________________________________________________________________________________________
# batch_normalization_865 (BatchN (None, None, None, 9 288         conv2d_866[0][0]
# __________________________________________________________________________________________________
# activation_862 (Activation)     (None, None, None, 4 0           batch_normalization_862[0][0]
# __________________________________________________________________________________________________
# activation_865 (Activation)     (None, None, None, 9 0           batch_normalization_865[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_82 (AveragePo (None, None, None, 2 0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_862 (Conv2D)             (None, None, None, 6 18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_864 (Conv2D)             (None, None, None, 6 76800       activation_862[0][0]
# __________________________________________________________________________________________________
# conv2d_867 (Conv2D)             (None, None, None, 9 82944       activation_865[0][0]
# __________________________________________________________________________________________________
# conv2d_868 (Conv2D)             (None, None, None, 6 18432       average_pooling2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_861 (BatchN (None, None, None, 6 192         conv2d_862[0][0]
# __________________________________________________________________________________________________
# batch_normalization_863 (BatchN (None, None, None, 6 192         conv2d_864[0][0]
# __________________________________________________________________________________________________
# batch_normalization_866 (BatchN (None, None, None, 9 288         conv2d_867[0][0]
# __________________________________________________________________________________________________
# batch_normalization_867 (BatchN (None, None, None, 6 192         conv2d_868[0][0]
# __________________________________________________________________________________________________
# activation_861 (Activation)     (None, None, None, 6 0           batch_normalization_861[0][0]
# __________________________________________________________________________________________________
# activation_863 (Activation)     (None, None, None, 6 0           batch_normalization_863[0][0]
# __________________________________________________________________________________________________
# activation_866 (Activation)     (None, None, None, 9 0           batch_normalization_866[0][0]
# __________________________________________________________________________________________________
# activation_867 (Activation)     (None, None, None, 6 0           batch_normalization_867[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, None, None, 2 0           activation_861[0][0]
#                                                                  activation_863[0][0]
#                                                                  activation_866[0][0]
#                                                                  activation_867[0][0]
# __________________________________________________________________________________________________
# conv2d_870 (Conv2D)             (None, None, None, 6 18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_869 (BatchN (None, None, None, 6 192         conv2d_870[0][0]
# __________________________________________________________________________________________________
# activation_869 (Activation)     (None, None, None, 6 0           batch_normalization_869[0][0]
# __________________________________________________________________________________________________
# conv2d_871 (Conv2D)             (None, None, None, 9 55296       activation_869[0][0]
# __________________________________________________________________________________________________
# batch_normalization_870 (BatchN (None, None, None, 9 288         conv2d_871[0][0]
# __________________________________________________________________________________________________
# activation_870 (Activation)     (None, None, None, 9 0           batch_normalization_870[0][0]
# __________________________________________________________________________________________________
# conv2d_869 (Conv2D)             (None, None, None, 3 995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_872 (Conv2D)             (None, None, None, 9 82944       activation_870[0][0]
# __________________________________________________________________________________________________
# batch_normalization_868 (BatchN (None, None, None, 3 1152        conv2d_869[0][0]
# __________________________________________________________________________________________________
# batch_normalization_871 (BatchN (None, None, None, 9 288         conv2d_872[0][0]
# __________________________________________________________________________________________________
# activation_868 (Activation)     (None, None, None, 3 0           batch_normalization_868[0][0]
# __________________________________________________________________________________________________
# activation_871 (Activation)     (None, None, None, 9 0           batch_normalization_871[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_38 (MaxPooling2D) (None, None, None, 2 0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, None, None, 7 0           activation_868[0][0]
#                                                                  activation_871[0][0]
#                                                                  max_pooling2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_877 (Conv2D)             (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_876 (BatchN (None, None, None, 1 384         conv2d_877[0][0]
# __________________________________________________________________________________________________
# activation_876 (Activation)     (None, None, None, 1 0           batch_normalization_876[0][0]
# __________________________________________________________________________________________________
# conv2d_878 (Conv2D)             (None, None, None, 1 114688      activation_876[0][0]
# __________________________________________________________________________________________________
# batch_normalization_877 (BatchN (None, None, None, 1 384         conv2d_878[0][0]
# __________________________________________________________________________________________________
# activation_877 (Activation)     (None, None, None, 1 0           batch_normalization_877[0][0]
# __________________________________________________________________________________________________
# conv2d_874 (Conv2D)             (None, None, None, 1 98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_879 (Conv2D)             (None, None, None, 1 114688      activation_877[0][0]
# __________________________________________________________________________________________________
# batch_normalization_873 (BatchN (None, None, None, 1 384         conv2d_874[0][0]
# __________________________________________________________________________________________________
# batch_normalization_878 (BatchN (None, None, None, 1 384         conv2d_879[0][0]
# __________________________________________________________________________________________________
# activation_873 (Activation)     (None, None, None, 1 0           batch_normalization_873[0][0]
# __________________________________________________________________________________________________
# activation_878 (Activation)     (None, None, None, 1 0           batch_normalization_878[0][0]
# __________________________________________________________________________________________________
# conv2d_875 (Conv2D)             (None, None, None, 1 114688      activation_873[0][0]
# __________________________________________________________________________________________________
# conv2d_880 (Conv2D)             (None, None, None, 1 114688      activation_878[0][0]
# __________________________________________________________________________________________________
# batch_normalization_874 (BatchN (None, None, None, 1 384         conv2d_875[0][0]
# __________________________________________________________________________________________________
# batch_normalization_879 (BatchN (None, None, None, 1 384         conv2d_880[0][0]
# __________________________________________________________________________________________________
# activation_874 (Activation)     (None, None, None, 1 0           batch_normalization_874[0][0]
# __________________________________________________________________________________________________
# activation_879 (Activation)     (None, None, None, 1 0           batch_normalization_879[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_83 (AveragePo (None, None, None, 7 0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_873 (Conv2D)             (None, None, None, 1 147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_876 (Conv2D)             (None, None, None, 1 172032      activation_874[0][0]
# __________________________________________________________________________________________________
# conv2d_881 (Conv2D)             (None, None, None, 1 172032      activation_879[0][0]
# __________________________________________________________________________________________________
# conv2d_882 (Conv2D)             (None, None, None, 1 147456      average_pooling2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_872 (BatchN (None, None, None, 1 576         conv2d_873[0][0]
# __________________________________________________________________________________________________
# batch_normalization_875 (BatchN (None, None, None, 1 576         conv2d_876[0][0]
# __________________________________________________________________________________________________
# batch_normalization_880 (BatchN (None, None, None, 1 576         conv2d_881[0][0]
# __________________________________________________________________________________________________
# batch_normalization_881 (BatchN (None, None, None, 1 576         conv2d_882[0][0]
# __________________________________________________________________________________________________
# activation_872 (Activation)     (None, None, None, 1 0           batch_normalization_872[0][0]
# __________________________________________________________________________________________________
# activation_875 (Activation)     (None, None, None, 1 0           batch_normalization_875[0][0]
# __________________________________________________________________________________________________
# activation_880 (Activation)     (None, None, None, 1 0           batch_normalization_880[0][0]
# __________________________________________________________________________________________________
# activation_881 (Activation)     (None, None, None, 1 0           batch_normalization_881[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, None, None, 7 0           activation_872[0][0]
#                                                                  activation_875[0][0]
#                                                                  activation_880[0][0]
#                                                                  activation_881[0][0]
# __________________________________________________________________________________________________
# conv2d_887 (Conv2D)             (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_886 (BatchN (None, None, None, 1 480         conv2d_887[0][0]
# __________________________________________________________________________________________________
# activation_886 (Activation)     (None, None, None, 1 0           batch_normalization_886[0][0]
# __________________________________________________________________________________________________
# conv2d_888 (Conv2D)             (None, None, None, 1 179200      activation_886[0][0]
# __________________________________________________________________________________________________
# batch_normalization_887 (BatchN (None, None, None, 1 480         conv2d_888[0][0]
# __________________________________________________________________________________________________
# activation_887 (Activation)     (None, None, None, 1 0           batch_normalization_887[0][0]
# __________________________________________________________________________________________________
# conv2d_884 (Conv2D)             (None, None, None, 1 122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_889 (Conv2D)             (None, None, None, 1 179200      activation_887[0][0]
# __________________________________________________________________________________________________
# batch_normalization_883 (BatchN (None, None, None, 1 480         conv2d_884[0][0]
# __________________________________________________________________________________________________
# batch_normalization_888 (BatchN (None, None, None, 1 480         conv2d_889[0][0]
# __________________________________________________________________________________________________
# activation_883 (Activation)     (None, None, None, 1 0           batch_normalization_883[0][0]
# __________________________________________________________________________________________________
# activation_888 (Activation)     (None, None, None, 1 0           batch_normalization_888[0][0]
# __________________________________________________________________________________________________
# conv2d_885 (Conv2D)             (None, None, None, 1 179200      activation_883[0][0]
# __________________________________________________________________________________________________
# conv2d_890 (Conv2D)             (None, None, None, 1 179200      activation_888[0][0]
# __________________________________________________________________________________________________
# batch_normalization_884 (BatchN (None, None, None, 1 480         conv2d_885[0][0]
# __________________________________________________________________________________________________
# batch_normalization_889 (BatchN (None, None, None, 1 480         conv2d_890[0][0]
# __________________________________________________________________________________________________
# activation_884 (Activation)     (None, None, None, 1 0           batch_normalization_884[0][0]
# __________________________________________________________________________________________________
# activation_889 (Activation)     (None, None, None, 1 0           batch_normalization_889[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_84 (AveragePo (None, None, None, 7 0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_883 (Conv2D)             (None, None, None, 1 147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_886 (Conv2D)             (None, None, None, 1 215040      activation_884[0][0]
# __________________________________________________________________________________________________
# conv2d_891 (Conv2D)             (None, None, None, 1 215040      activation_889[0][0]
# __________________________________________________________________________________________________
# conv2d_892 (Conv2D)             (None, None, None, 1 147456      average_pooling2d_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_882 (BatchN (None, None, None, 1 576         conv2d_883[0][0]
# __________________________________________________________________________________________________
# batch_normalization_885 (BatchN (None, None, None, 1 576         conv2d_886[0][0]
# __________________________________________________________________________________________________
# batch_normalization_890 (BatchN (None, None, None, 1 576         conv2d_891[0][0]
# __________________________________________________________________________________________________
# batch_normalization_891 (BatchN (None, None, None, 1 576         conv2d_892[0][0]
# __________________________________________________________________________________________________
# activation_882 (Activation)     (None, None, None, 1 0           batch_normalization_882[0][0]
# __________________________________________________________________________________________________
# activation_885 (Activation)     (None, None, None, 1 0           batch_normalization_885[0][0]
# __________________________________________________________________________________________________
# activation_890 (Activation)     (None, None, None, 1 0           batch_normalization_890[0][0]
# __________________________________________________________________________________________________
# activation_891 (Activation)     (None, None, None, 1 0           batch_normalization_891[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, None, None, 7 0           activation_882[0][0]
#                                                                  activation_885[0][0]
#                                                                  activation_890[0][0]
#                                                                  activation_891[0][0]
# __________________________________________________________________________________________________
# conv2d_897 (Conv2D)             (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_896 (BatchN (None, None, None, 1 480         conv2d_897[0][0]
# __________________________________________________________________________________________________
# activation_896 (Activation)     (None, None, None, 1 0           batch_normalization_896[0][0]
# __________________________________________________________________________________________________
# conv2d_898 (Conv2D)             (None, None, None, 1 179200      activation_896[0][0]
# __________________________________________________________________________________________________
# batch_normalization_897 (BatchN (None, None, None, 1 480         conv2d_898[0][0]
# __________________________________________________________________________________________________
# activation_897 (Activation)     (None, None, None, 1 0           batch_normalization_897[0][0]
# __________________________________________________________________________________________________
# conv2d_894 (Conv2D)             (None, None, None, 1 122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_899 (Conv2D)             (None, None, None, 1 179200      activation_897[0][0]
# __________________________________________________________________________________________________
# batch_normalization_893 (BatchN (None, None, None, 1 480         conv2d_894[0][0]
# __________________________________________________________________________________________________
# batch_normalization_898 (BatchN (None, None, None, 1 480         conv2d_899[0][0]
# __________________________________________________________________________________________________
# activation_893 (Activation)     (None, None, None, 1 0           batch_normalization_893[0][0]
# __________________________________________________________________________________________________
# activation_898 (Activation)     (None, None, None, 1 0           batch_normalization_898[0][0]
# __________________________________________________________________________________________________
# conv2d_895 (Conv2D)             (None, None, None, 1 179200      activation_893[0][0]
# __________________________________________________________________________________________________
# conv2d_900 (Conv2D)             (None, None, None, 1 179200      activation_898[0][0]
# __________________________________________________________________________________________________
# batch_normalization_894 (BatchN (None, None, None, 1 480         conv2d_895[0][0]
# __________________________________________________________________________________________________
# batch_normalization_899 (BatchN (None, None, None, 1 480         conv2d_900[0][0]
# __________________________________________________________________________________________________
# activation_894 (Activation)     (None, None, None, 1 0           batch_normalization_894[0][0]
# __________________________________________________________________________________________________
# activation_899 (Activation)     (None, None, None, 1 0           batch_normalization_899[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_85 (AveragePo (None, None, None, 7 0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_893 (Conv2D)             (None, None, None, 1 147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_896 (Conv2D)             (None, None, None, 1 215040      activation_894[0][0]
# __________________________________________________________________________________________________
# conv2d_901 (Conv2D)             (None, None, None, 1 215040      activation_899[0][0]
# __________________________________________________________________________________________________
# conv2d_902 (Conv2D)             (None, None, None, 1 147456      average_pooling2d_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_892 (BatchN (None, None, None, 1 576         conv2d_893[0][0]
# __________________________________________________________________________________________________
# batch_normalization_895 (BatchN (None, None, None, 1 576         conv2d_896[0][0]
# __________________________________________________________________________________________________
# batch_normalization_900 (BatchN (None, None, None, 1 576         conv2d_901[0][0]
# __________________________________________________________________________________________________
# batch_normalization_901 (BatchN (None, None, None, 1 576         conv2d_902[0][0]
# __________________________________________________________________________________________________
# activation_892 (Activation)     (None, None, None, 1 0           batch_normalization_892[0][0]
# __________________________________________________________________________________________________
# activation_895 (Activation)     (None, None, None, 1 0           batch_normalization_895[0][0]
# __________________________________________________________________________________________________
# activation_900 (Activation)     (None, None, None, 1 0           batch_normalization_900[0][0]
# __________________________________________________________________________________________________
# activation_901 (Activation)     (None, None, None, 1 0           batch_normalization_901[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, None, None, 7 0           activation_892[0][0]
#                                                                  activation_895[0][0]
#                                                                  activation_900[0][0]
#                                                                  activation_901[0][0]
# __________________________________________________________________________________________________
# conv2d_907 (Conv2D)             (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_906 (BatchN (None, None, None, 1 576         conv2d_907[0][0]
# __________________________________________________________________________________________________
# activation_906 (Activation)     (None, None, None, 1 0           batch_normalization_906[0][0]
# __________________________________________________________________________________________________
# conv2d_908 (Conv2D)             (None, None, None, 1 258048      activation_906[0][0]
# __________________________________________________________________________________________________
# batch_normalization_907 (BatchN (None, None, None, 1 576         conv2d_908[0][0]
# __________________________________________________________________________________________________
# activation_907 (Activation)     (None, None, None, 1 0           batch_normalization_907[0][0]
# __________________________________________________________________________________________________
# conv2d_904 (Conv2D)             (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_909 (Conv2D)             (None, None, None, 1 258048      activation_907[0][0]
# __________________________________________________________________________________________________
# batch_normalization_903 (BatchN (None, None, None, 1 576         conv2d_904[0][0]
# __________________________________________________________________________________________________
# batch_normalization_908 (BatchN (None, None, None, 1 576         conv2d_909[0][0]
# __________________________________________________________________________________________________
# activation_903 (Activation)     (None, None, None, 1 0           batch_normalization_903[0][0]
# __________________________________________________________________________________________________
# activation_908 (Activation)     (None, None, None, 1 0           batch_normalization_908[0][0]
# __________________________________________________________________________________________________
# conv2d_905 (Conv2D)             (None, None, None, 1 258048      activation_903[0][0]
# __________________________________________________________________________________________________
# conv2d_910 (Conv2D)             (None, None, None, 1 258048      activation_908[0][0]
# __________________________________________________________________________________________________
# batch_normalization_904 (BatchN (None, None, None, 1 576         conv2d_905[0][0]
# __________________________________________________________________________________________________
# batch_normalization_909 (BatchN (None, None, None, 1 576         conv2d_910[0][0]
# __________________________________________________________________________________________________
# activation_904 (Activation)     (None, None, None, 1 0           batch_normalization_904[0][0]
# __________________________________________________________________________________________________
# activation_909 (Activation)     (None, None, None, 1 0           batch_normalization_909[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_86 (AveragePo (None, None, None, 7 0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_903 (Conv2D)             (None, None, None, 1 147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_906 (Conv2D)             (None, None, None, 1 258048      activation_904[0][0]
# __________________________________________________________________________________________________
# conv2d_911 (Conv2D)             (None, None, None, 1 258048      activation_909[0][0]
# __________________________________________________________________________________________________
# conv2d_912 (Conv2D)             (None, None, None, 1 147456      average_pooling2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_902 (BatchN (None, None, None, 1 576         conv2d_903[0][0]
# __________________________________________________________________________________________________
# batch_normalization_905 (BatchN (None, None, None, 1 576         conv2d_906[0][0]
# __________________________________________________________________________________________________
# batch_normalization_910 (BatchN (None, None, None, 1 576         conv2d_911[0][0]
# __________________________________________________________________________________________________
# batch_normalization_911 (BatchN (None, None, None, 1 576         conv2d_912[0][0]
# __________________________________________________________________________________________________
# activation_902 (Activation)     (None, None, None, 1 0           batch_normalization_902[0][0]
# __________________________________________________________________________________________________
# activation_905 (Activation)     (None, None, None, 1 0           batch_normalization_905[0][0]
# __________________________________________________________________________________________________
# activation_910 (Activation)     (None, None, None, 1 0           batch_normalization_910[0][0]
# __________________________________________________________________________________________________
# activation_911 (Activation)     (None, None, None, 1 0           batch_normalization_911[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, None, None, 7 0           activation_902[0][0]
#                                                                  activation_905[0][0]
#                                                                  activation_910[0][0]
#                                                                  activation_911[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# batch_normalization_913 (BatchN (None, None, None, 3 960         conv2d_914[0][0]
# __________________________________________________________________________________________________
# batch_normalization_917 (BatchN (None, None, None, 1 576         conv2d_918[0][0]
# __________________________________________________________________________________________________
# activation_913 (Activation)     (None, None, None, 3 0           batch_normalization_913[0][0]
# __________________________________________________________________________________________________
# activation_917 (Activation)     (None, None, None, 1 0           batch_normalization_917[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_39 (MaxPooling2D) (None, None, None, 7 0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, None, None, 1 0           activation_913[0][0]
#                                                                  activation_917[0][0]
#                                                                  max_pooling2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_923 (Conv2D)             (None, None, None, 4 573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_922 (BatchN (None, None, None, 4 1344        conv2d_923[0][0]
# __________________________________________________________________________________________________
# activation_922 (Activation)     (None, None, None, 4 0           batch_normalization_922[0][0]
# __________________________________________________________________________________________________
# conv2d_920 (Conv2D)             (None, None, None, 3 491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_924 (Conv2D)             (None, None, None, 3 1548288     activation_922[0][0]
# __________________________________________________________________________________________________
# batch_normalization_919 (BatchN (None, None, None, 3 1152        conv2d_920[0][0]
# __________________________________________________________________________________________________
# batch_normalization_923 (BatchN (None, None, None, 3 1152        conv2d_924[0][0]
# __________________________________________________________________________________________________
# activation_919 (Activation)     (None, None, None, 3 0           batch_normalization_919[0][0]
# __________________________________________________________________________________________________
# activation_923 (Activation)     (None, None, None, 3 0           batch_normalization_923[0][0]
# __________________________________________________________________________________________________
# conv2d_921 (Conv2D)             (None, None, None, 3 442368      activation_919[0][0]
# __________________________________________________________________________________________________
# conv2d_922 (Conv2D)             (None, None, None, 3 442368      activation_919[0][0]
# __________________________________________________________________________________________________
# conv2d_925 (Conv2D)             (None, None, None, 3 442368      activation_923[0][0]
# __________________________________________________________________________________________________
# conv2d_926 (Conv2D)             (None, None, None, 3 442368      activation_923[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_87 (AveragePo (None, None, None, 1 0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_919 (Conv2D)             (None, None, None, 3 409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_920 (BatchN (None, None, None, 3 1152        conv2d_921[0][0]
# __________________________________________________________________________________________________
# batch_normalization_921 (BatchN (None, None, None, 3 1152        conv2d_922[0][0]
# __________________________________________________________________________________________________
# batch_normalization_924 (BatchN (None, None, None, 3 1152        conv2d_925[0][0]
# __________________________________________________________________________________________________
# batch_normalization_925 (BatchN (None, None, None, 3 1152        conv2d_926[0][0]
# __________________________________________________________________________________________________
# conv2d_927 (Conv2D)             (None, None, None, 1 245760      average_pooling2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_918 (BatchN (None, None, None, 3 960         conv2d_919[0][0]
# __________________________________________________________________________________________________
# activation_920 (Activation)     (None, None, None, 3 0           batch_normalization_920[0][0]
# __________________________________________________________________________________________________
# activation_921 (Activation)     (None, None, None, 3 0           batch_normalization_921[0][0]
# __________________________________________________________________________________________________
# activation_924 (Activation)     (None, None, None, 3 0           batch_normalization_924[0][0]
# __________________________________________________________________________________________________
# activation_925 (Activation)     (None, None, None, 3 0           batch_normalization_925[0][0]
# __________________________________________________________________________________________________
# batch_normalization_926 (BatchN (None, None, None, 1 576         conv2d_927[0][0]
# __________________________________________________________________________________________________
# activation_918 (Activation)     (None, None, None, 3 0           batch_normalization_918[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, None, None, 7 0           activation_920[0][0]
#                                                                  activation_921[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, None, None, 7 0           activation_924[0][0]
#                                                                  activation_925[0][0]
# __________________________________________________________________________________________________
# activation_926 (Activation)     (None, None, None, 1 0           batch_normalization_926[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, None, None, 2 0           activation_918[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_17[0][0]
#                                                                  activation_926[0][0]
# __________________________________________________________________________________________________
# conv2d_932 (Conv2D)             (None, None, None, 4 917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_931 (BatchN (None, None, None, 4 1344        conv2d_932[0][0]
# __________________________________________________________________________________________________
# activation_931 (Activation)     (None, None, None, 4 0           batch_normalization_931[0][0]
# __________________________________________________________________________________________________
# conv2d_929 (Conv2D)             (None, None, None, 3 786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_933 (Conv2D)             (None, None, None, 3 1548288     activation_931[0][0]
# __________________________________________________________________________________________________
# batch_normalization_928 (BatchN (None, None, None, 3 1152        conv2d_929[0][0]
# __________________________________________________________________________________________________
# batch_normalization_932 (BatchN (None, None, None, 3 1152        conv2d_933[0][0]
# __________________________________________________________________________________________________
# activation_928 (Activation)     (None, None, None, 3 0           batch_normalization_928[0][0]
# __________________________________________________________________________________________________
# activation_932 (Activation)     (None, None, None, 3 0           batch_normalization_932[0][0]
# __________________________________________________________________________________________________
# conv2d_930 (Conv2D)             (None, None, None, 3 442368      activation_928[0][0]
# __________________________________________________________________________________________________
# conv2d_931 (Conv2D)             (None, None, None, 3 442368      activation_928[0][0]
# __________________________________________________________________________________________________
# conv2d_934 (Conv2D)             (None, None, None, 3 442368      activation_932[0][0]
# __________________________________________________________________________________________________
# conv2d_935 (Conv2D)             (None, None, None, 3 442368      activation_932[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_88 (AveragePo (None, None, None, 2 0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_928 (Conv2D)             (None, None, None, 3 655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_929 (BatchN (None, None, None, 3 1152        conv2d_930[0][0]
# __________________________________________________________________________________________________
# batch_normalization_930 (BatchN (None, None, None, 3 1152        conv2d_931[0][0]
# __________________________________________________________________________________________________
# batch_normalization_933 (BatchN (None, None, None, 3 1152        conv2d_934[0][0]
# __________________________________________________________________________________________________
# batch_normalization_934 (BatchN (None, None, None, 3 1152        conv2d_935[0][0]
# __________________________________________________________________________________________________
# conv2d_936 (Conv2D)             (None, None, None, 1 393216      average_pooling2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_927 (BatchN (None, None, None, 3 960         conv2d_928[0][0]
# __________________________________________________________________________________________________
# activation_929 (Activation)     (None, None, None, 3 0           batch_normalization_929[0][0]
# __________________________________________________________________________________________________
# activation_930 (Activation)     (None, None, None, 3 0           batch_normalization_930[0][0]
# __________________________________________________________________________________________________
# activation_933 (Activation)     (None, None, None, 3 0           batch_normalization_933[0][0]
# __________________________________________________________________________________________________
# activation_934 (Activation)     (None, None, None, 3 0           batch_normalization_934[0][0]
# __________________________________________________________________________________________________
# batch_normalization_935 (BatchN (None, None, None, 1 576         conv2d_936[0][0]
# __________________________________________________________________________________________________
# activation_927 (Activation)     (None, None, None, 3 0           batch_normalization_927[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, None, None, 7 0           activation_929[0][0]
#                                                                  activation_930[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, None, None, 7 0           activation_933[0][0]
#                                                                  activation_934[0][0]
# __________________________________________________________________________________________________
# activation_935 (Activation)     (None, None, None, 1 0           batch_normalization_935[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, None, None, 2 0           activation_927[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_18[0][0]
#                                                                  activation_935[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 2048)         0           mixed10[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 2048)         0           global_average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 128)          262272      dropout_10[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 64)           8256        dense_30[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 3)            195         dense_31[0][0]
# ==================================================================================================
# Total params: 22,073,507
# Trainable params: 22,039,075
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
history = fit_model(model)
evaluate_model(history)
# Out:
# Epoch 1/100
# 123/123 [==============================] - 27s 217ms/step - loss: 0.6314 - accuracy: 0.7500 - val_loss: 5.9773 - val_accuracy: 0.5667
# Epoch 2/100
# 123/123 [==============================] - 25s 207ms/step - loss: 0.4973 - accuracy: 0.8183 - val_loss: 3.2287 - val_accuracy: 0.5600
# Epoch 3/100
# 123/123 [==============================] - 25s 207ms/step - loss: 0.3699 - accuracy: 0.8618 - val_loss: 11.5039 - val_accuracy: 0.6267
# Epoch 4/100
# 123/123 [==============================] - 25s 206ms/step - loss: 0.3505 - accuracy: 0.8768 - val_loss: 2.8108 - val_accuracy: 0.5600
# Epoch 5/100
# 123/123 [==============================] - 25s 204ms/step - loss: 0.3454 - accuracy: 0.8744 - val_loss: 8.0962 - val_accuracy: 0.5267
# Epoch 6/100
# 123/123 [==============================] - 25s 204ms/step - loss: 0.3422 - accuracy: 0.8756 - val_loss: 3.7091 - val_accuracy: 0.3800
# Epoch 7/100
# 123/123 [==============================] - 25s 206ms/step - loss: 0.2713 - accuracy: 0.8976 - val_loss: 1.7606 - val_accuracy: 0.5467
# Epoch 8/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.2524 - accuracy: 0.9138 - val_loss: 1.6042 - val_accuracy: 0.6933
# Epoch 9/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.2078 - accuracy: 0.9220 - val_loss: 1.6780 - val_accuracy: 0.5333
# Epoch 10/100
# 123/123 [==============================] - 26s 208ms/step - loss: 0.2399 - accuracy: 0.9159 - val_loss: 5.0392 - val_accuracy: 0.4533
# Epoch 11/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.2227 - accuracy: 0.9260 - val_loss: 1.5968 - val_accuracy: 0.5467
# Epoch 12/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.2361 - accuracy: 0.9183 - val_loss: 1.5243 - val_accuracy: 0.6733
# Epoch 13/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.2185 - accuracy: 0.9276 - val_loss: 1.1023 - val_accuracy: 0.6933
# Epoch 14/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.1962 - accuracy: 0.9341 - val_loss: 1.5303 - val_accuracy: 0.6933
# Epoch 15/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.2062 - accuracy: 0.9309 - val_loss: 0.9890 - val_accuracy: 0.7200
# Epoch 16/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.1762 - accuracy: 0.9394 - val_loss: 0.9137 - val_accuracy: 0.7333
# Epoch 17/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.1820 - accuracy: 0.9337 - val_loss: 2.7158 - val_accuracy: 0.6800
# Epoch 18/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.1824 - accuracy: 0.9411 - val_loss: 23.5449 - val_accuracy: 0.4000
# Epoch 19/100
# 123/123 [==============================] - 25s 205ms/step - loss: 0.1800 - accuracy: 0.9386 - val_loss: 2.5339 - val_accuracy: 0.7067
# Epoch 20/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.1331 - accuracy: 0.9504 - val_loss: 1.7470 - val_accuracy: 0.5867
# Epoch 21/100
# 123/123 [==============================] - 26s 214ms/step - loss: 0.1783 - accuracy: 0.9407 - val_loss: 3.8640 - val_accuracy: 0.5133
# Epoch 22/100
# 123/123 [==============================] - 26s 210ms/step - loss: 0.1590 - accuracy: 0.9402 - val_loss: 2.7070 - val_accuracy: 0.5667
# Epoch 23/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.1200 - accuracy: 0.9589 - val_loss: 2.7146 - val_accuracy: 0.6933
# Epoch 24/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.1537 - accuracy: 0.9439 - val_loss: 1.4465 - val_accuracy: 0.5733
# Epoch 25/100
# 123/123 [==============================] - 25s 204ms/step - loss: 0.1340 - accuracy: 0.9504 - val_loss: 1.1339 - val_accuracy: 0.7200
# Epoch 26/100
# 123/123 [==============================] - 25s 204ms/step - loss: 0.1741 - accuracy: 0.9398 - val_loss: 1.4105 - val_accuracy: 0.6800
# Epoch 27/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.1502 - accuracy: 0.9496 - val_loss: 2.4057 - val_accuracy: 0.4600
# Epoch 28/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.1391 - accuracy: 0.9476 - val_loss: 1.3846 - val_accuracy: 0.7133
# Epoch 29/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.1535 - accuracy: 0.9533 - val_loss: 1.3473 - val_accuracy: 0.7000
# Epoch 30/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0988 - accuracy: 0.9630 - val_loss: 1.6056 - val_accuracy: 0.6733
# Epoch 31/100
# 123/123 [==============================] - 25s 204ms/step - loss: 0.1500 - accuracy: 0.9451 - val_loss: 1.5273 - val_accuracy: 0.6867
# Epoch 32/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.1231 - accuracy: 0.9589 - val_loss: 1.1409 - val_accuracy: 0.6467
# Epoch 33/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.1407 - accuracy: 0.9520 - val_loss: 1.4285 - val_accuracy: 0.7400
# Epoch 34/100
# 123/123 [==============================] - 25s 206ms/step - loss: 0.1588 - accuracy: 0.9459 - val_loss: 1.2579 - val_accuracy: 0.7400
# Epoch 35/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.1364 - accuracy: 0.9472 - val_loss: 1.1063 - val_accuracy: 0.6933
# Epoch 36/100
# 123/123 [==============================] - 25s 201ms/step - loss: 0.1030 - accuracy: 0.9679 - val_loss: 1.2161 - val_accuracy: 0.7333
# Epoch 37/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.0998 - accuracy: 0.9683 - val_loss: 1.2908 - val_accuracy: 0.6267
# Epoch 38/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.1046 - accuracy: 0.9614 - val_loss: 1.6958 - val_accuracy: 0.6800
# Epoch 39/100
# 123/123 [==============================] - 25s 201ms/step - loss: 0.1316 - accuracy: 0.9585 - val_loss: 1.7098 - val_accuracy: 0.7400
# Epoch 40/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.1142 - accuracy: 0.9642 - val_loss: 1.3402 - val_accuracy: 0.7467
# Epoch 41/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.1150 - accuracy: 0.9646 - val_loss: 1.3474 - val_accuracy: 0.6800
# Epoch 42/100
# 123/123 [==============================] - 25s 204ms/step - loss: 0.0882 - accuracy: 0.9720 - val_loss: 1.4355 - val_accuracy: 0.7467
# Epoch 43/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.1248 - accuracy: 0.9618 - val_loss: 1.5113 - val_accuracy: 0.6667
# Epoch 44/100
# 123/123 [==============================] - 25s 201ms/step - loss: 0.1156 - accuracy: 0.9610 - val_loss: 1.6893 - val_accuracy: 0.6000
# Epoch 45/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.0904 - accuracy: 0.9711 - val_loss: 2.0781 - val_accuracy: 0.6267
# Epoch 46/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.0981 - accuracy: 0.9654 - val_loss: 1.9146 - val_accuracy: 0.6400
# Epoch 47/100
# 123/123 [==============================] - 25s 204ms/step - loss: 0.0878 - accuracy: 0.9728 - val_loss: 1.4058 - val_accuracy: 0.6667
# Epoch 48/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.1137 - accuracy: 0.9626 - val_loss: 1.4190 - val_accuracy: 0.6733
# Epoch 49/100
# 123/123 [==============================] - 25s 201ms/step - loss: 0.1069 - accuracy: 0.9654 - val_loss: 1.0578 - val_accuracy: 0.7133
# Epoch 50/100
# 123/123 [==============================] - 25s 201ms/step - loss: 0.1311 - accuracy: 0.9573 - val_loss: 2.0012 - val_accuracy: 0.6800
# Epoch 51/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.1107 - accuracy: 0.9622 - val_loss: 1.3260 - val_accuracy: 0.5933
# Epoch 52/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0810 - accuracy: 0.9748 - val_loss: 1.8736 - val_accuracy: 0.6267
# Epoch 53/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.0925 - accuracy: 0.9687 - val_loss: 2.1195 - val_accuracy: 0.6600
# Epoch 54/100
# 123/123 [==============================] - 25s 204ms/step - loss: 0.0954 - accuracy: 0.9720 - val_loss: 1.5930 - val_accuracy: 0.6800
# Epoch 55/100
# 123/123 [==============================] - 25s 199ms/step - loss: 0.0976 - accuracy: 0.9687 - val_loss: 1.7833 - val_accuracy: 0.7200
# Epoch 56/100
# 123/123 [==============================] - 25s 200ms/step - loss: 0.0769 - accuracy: 0.9728 - val_loss: 1.9290 - val_accuracy: 0.7000
# Epoch 57/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0695 - accuracy: 0.9772 - val_loss: 1.3216 - val_accuracy: 0.7133
# Epoch 58/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0732 - accuracy: 0.9772 - val_loss: 1.1668 - val_accuracy: 0.6867
# Epoch 59/100
# 123/123 [==============================] - 25s 206ms/step - loss: 0.0710 - accuracy: 0.9793 - val_loss: 1.3455 - val_accuracy: 0.7467
# Epoch 60/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0847 - accuracy: 0.9732 - val_loss: 1.6090 - val_accuracy: 0.6400
# Epoch 61/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.0805 - accuracy: 0.9736 - val_loss: 3.2756 - val_accuracy: 0.6800
# Epoch 62/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0683 - accuracy: 0.9801 - val_loss: 1.7284 - val_accuracy: 0.5000
# Epoch 63/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.0674 - accuracy: 0.9776 - val_loss: 0.9395 - val_accuracy: 0.7467
# Epoch 64/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.0871 - accuracy: 0.9707 - val_loss: 1.4971 - val_accuracy: 0.5800
# Epoch 65/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.0841 - accuracy: 0.9728 - val_loss: 1.8681 - val_accuracy: 0.5867
# Epoch 66/100
# 123/123 [==============================] - 25s 204ms/step - loss: 0.1048 - accuracy: 0.9683 - val_loss: 1.7023 - val_accuracy: 0.5400
# Epoch 67/100
# 123/123 [==============================] - 25s 204ms/step - loss: 0.0893 - accuracy: 0.9720 - val_loss: 1.8626 - val_accuracy: 0.7133
# Epoch 68/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0647 - accuracy: 0.9780 - val_loss: 1.2686 - val_accuracy: 0.6800
# Epoch 69/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0481 - accuracy: 0.9841 - val_loss: 2.2486 - val_accuracy: 0.6867
# Epoch 70/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.0734 - accuracy: 0.9724 - val_loss: 1.8071 - val_accuracy: 0.6600
# Epoch 71/100
# 123/123 [==============================] - 25s 206ms/step - loss: 0.0592 - accuracy: 0.9793 - val_loss: 0.9390 - val_accuracy: 0.6933
# Epoch 72/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.0571 - accuracy: 0.9833 - val_loss: 2.3037 - val_accuracy: 0.6000
# Epoch 73/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.0872 - accuracy: 0.9760 - val_loss: 1.6857 - val_accuracy: 0.5533
# Epoch 74/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.0689 - accuracy: 0.9772 - val_loss: 1.5797 - val_accuracy: 0.6467
# Epoch 75/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0565 - accuracy: 0.9797 - val_loss: 1.6839 - val_accuracy: 0.6067
# Epoch 76/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0436 - accuracy: 0.9862 - val_loss: 1.6548 - val_accuracy: 0.7133
# Epoch 77/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.0541 - accuracy: 0.9813 - val_loss: 3.0781 - val_accuracy: 0.5600
# Epoch 78/100
# 123/123 [==============================] - 25s 204ms/step - loss: 0.1020 - accuracy: 0.9711 - val_loss: 1.8126 - val_accuracy: 0.5533
# Epoch 79/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.0519 - accuracy: 0.9829 - val_loss: 1.8269 - val_accuracy: 0.6933
# Epoch 80/100
# 123/123 [==============================] - 25s 205ms/step - loss: 0.0520 - accuracy: 0.9841 - val_loss: 1.6697 - val_accuracy: 0.6800
# Epoch 81/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0924 - accuracy: 0.9752 - val_loss: 10.8573 - val_accuracy: 0.3867
# Epoch 82/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0583 - accuracy: 0.9805 - val_loss: 1.2794 - val_accuracy: 0.7333
# Epoch 83/100
# 123/123 [==============================] - 25s 203ms/step - loss: 0.0552 - accuracy: 0.9809 - val_loss: 1.2305 - val_accuracy: 0.7467
# Epoch 84/100
# 123/123 [==============================] - 25s 205ms/step - loss: 0.0472 - accuracy: 0.9850 - val_loss: 1.1735 - val_accuracy: 0.6533
# Epoch 85/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0786 - accuracy: 0.9756 - val_loss: 2.3780 - val_accuracy: 0.5733
# Epoch 86/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0592 - accuracy: 0.9817 - val_loss: 4.5515 - val_accuracy: 0.6733
# Epoch 87/100
# 123/123 [==============================] - 25s 201ms/step - loss: 0.0492 - accuracy: 0.9829 - val_loss: 2.0973 - val_accuracy: 0.7200
# Epoch 88/100
# 123/123 [==============================] - 25s 201ms/step - loss: 0.0933 - accuracy: 0.9728 - val_loss: 2.5699 - val_accuracy: 0.7467
# Epoch 89/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0848 - accuracy: 0.9724 - val_loss: 2.4485 - val_accuracy: 0.6800
# Epoch 90/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0844 - accuracy: 0.9764 - val_loss: 4.6163 - val_accuracy: 0.6533
# Epoch 91/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0403 - accuracy: 0.9862 - val_loss: 1.9072 - val_accuracy: 0.6733
# Epoch 92/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0458 - accuracy: 0.9841 - val_loss: 2.3783 - val_accuracy: 0.6333
# Epoch 93/100
# 123/123 [==============================] - 25s 201ms/step - loss: 0.0426 - accuracy: 0.9874 - val_loss: 5.6202 - val_accuracy: 0.6467
# Epoch 94/100
# 123/123 [==============================] - 25s 201ms/step - loss: 0.0401 - accuracy: 0.9866 - val_loss: 2.1022 - val_accuracy: 0.6867
# Epoch 95/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0902 - accuracy: 0.9768 - val_loss: 1.7906 - val_accuracy: 0.6067
# Epoch 96/100
# 123/123 [==============================] - 25s 206ms/step - loss: 0.0356 - accuracy: 0.9882 - val_loss: 3.0711 - val_accuracy: 0.5600
# Epoch 97/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0307 - accuracy: 0.9911 - val_loss: 1.7583 - val_accuracy: 0.6867
# Epoch 98/100
# 123/123 [==============================] - 25s 201ms/step - loss: 0.0572 - accuracy: 0.9813 - val_loss: 1.9302 - val_accuracy: 0.5467
# Epoch 99/100
# 123/123 [==============================] - 25s 202ms/step - loss: 0.0374 - accuracy: 0.9874 - val_loss: 2.2497 - val_accuracy: 0.6933
# Epoch 100/100
# 123/123 [==============================] - 25s 201ms/step - loss: 0.0892 - accuracy: 0.9744 - val_loss: 1.7551 - val_accuracy: 0.6867

# %%
classify_tumor(model, testing_img_paths)
# Out:
# MRI Scan #1)
# MRI Scan #2)
# MRI Scan #3)
# MRI Scan #4)
# MRI Scan #5)
# MRI Scan #6)
# MRI Scan #7)
# MRI Scan #8)
# MRI Scan #9)
# MRI Scan #10)
# MRI Scan #11)
# MRI Scan #12)
# MRI Scan #13)
# MRI Scan #14)
# MRI Scan #15)
# MRI Scan #16)
# MRI Scan #17)
# MRI Scan #18)
# MRI Scan #19)
# MRI Scan #20)
# MRI Scan #21)
# MRI Scan #22)
# MRI Scan #23)
# MRI Scan #24)
# MRI Scan #25)
# MRI Scan #26)
# MRI Scan #27)
# MRI Scan #28)
# MRI Scan #29)
# MRI Scan #30)
# MRI Scan #31)
# MRI Scan #32)
# MRI Scan #33)
# MRI Scan #34)
# MRI Scan #35)
# MRI Scan #36)
# MRI Scan #37)
# MRI Scan #38)
# MRI Scan #39)
# MRI Scan #40)
# MRI Scan #41)
# MRI Scan #42)
# MRI Scan #43)
# MRI Scan #44)
# MRI Scan #45)
# MRI Scan #46)
# MRI Scan #47)
# MRI Scan #48)
# MRI Scan #49)
# MRI Scan #50)
# MRI Scan #51)
# MRI Scan #52)
# MRI Scan #53)
# MRI Scan #54)
# MRI Scan #55)
# MRI Scan #56)
# MRI Scan #57)
# MRI Scan #58)
# MRI Scan #59)
# MRI Scan #60)
